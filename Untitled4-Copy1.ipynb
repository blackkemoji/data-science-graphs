# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
df.head(6)
# Out:
#      NAME  AGE      CITY  SALARY
# 0   ERICK   21  NEW YORK   98000
# 1    DAVE   34        LA   78000
# 2    RITA   45        DC   65000
# 3  DERICK   43     PARIS   56790
# 4    MARY   23     DUBAI   56789

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv(r'C:\Users\Erick Mwangi\Documents\SALARY.csv')
NAME=df["NAME"]
SALARY=df["SALARY"]
plt.bar(NAME,SALARY,label="salary",color='red')
plt.xlabel("NAME")
plt.ylabel("SALARY")
plt.title("SALARY DISTRIBUTION")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv(r'C:\Users\Erick Mwangi\Documents\SALARY.csv')

# %%
SALARY=df["SALARY"]
NAME=df["NAME"]
colors=['r','w','g','b','y']
explode=(0.1,0,0,0,0,)
plt.pie(SALARY,explode=explode,colors=colors,labels=NAME,autopct=CC)
plt.title('PIE SALARY DISTRIBUTION')
plt.show()

# %%
SALARY=df["SALARY"]
CITY=df['CITY']
colors=('r','g','y','w','b')
explode=[0.1,0.1,0,0,0]
plt.pie(SALARY,colors=colors,explode=explode,labels=CITY,autopct="%.1f%%")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv(r'C:\Users\Erick Mwangi\Documents\SALARY.csv')
NAME=df['NAME']
AGE=df['AGE']
plt.plot(NAME,AGE,label='AGE',color='b',)
plt.plot()
plt.xlabel('NAME')
plt.ylabel('AGE')
plt.title("NAME SALARY LINE")
plt.legend()
plt.show()

# %%
CITY=df["CITY"]
SALARY=df["SALARY"]
plt.plot(CITY,SALARY,label='SALARY DISTRIBUTION BY CITY',color='g')
plt.plot()
plt.xlabel("CITY")
plt.ylabel("SALARY")
plt.title("SALARY DISTRIBUTION")
plt.legend()
plt.show()
